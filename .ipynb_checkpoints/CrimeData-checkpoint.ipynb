# %%
import os
import pandas as pd
import numpy as nm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('calls.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77794 entries, 0 to 77793
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           77794 non-null  object
#  1   agency        77794 non-null  object
#  2   coords        74394 non-null  object
#  3   district      77794 non-null  object
#  4   incident      77794 non-null  object
#  5   location      77794 non-null  object
#  6   status        77794 non-null  object
#  7   timeReceived  77794 non-null  object
# dtypes: object(8)
# memory usage: 4.7+ MB

# %%
df.head()
# Out:
#                                 _id agency  \
# 0  0411a692604fc30d2b7e90768bea27cb    RFD
# 1  a6778ad2a905749daa2d7ba3571b5943    RPD
# 2  ea9f720bdb4e40f25c6da4978692fd9d    RPD
# 3  d34129688e6724e10872e708e8476b43    RPD
# 4  7e22a1550c625e11e2c6905b7c1c9f1f    RPD
#
#                                    coords  district  \
# 0  [37.52257549999999,-77.48004999999999]  Richmond
# 1                 [37.5469025,-77.542215]  Richmond
# 2                [37.5473731,-77.4366354]  Richmond
# 3                  [37.514049,-77.489561]  Richmond
# 4                [37.5773242,-77.4625667]  Richmond
#
#                                             incident  \
# 0  # UTILITY INCIDENT , GAS LEAK - RUPTURED MAIN ...
# 1                        BURGLAR ALARM , INVESTIGATE
# 2                    TRAFFIC COMPLAINT , INVESTIGATE
# 3                 LARCENY , DPR Call - Take a Report
# 4                              DISORDERLY , NUISANCE
#
#                       location  status              timeReceived
# 0           1800-BLK W 45TH ST  Closed  2022-01-28T16:09:00.000Z
# 1        3700-BLK WAKEFIELD RD  Closed  2022-01-28T16:07:00.000Z
# 2     MOSBY ST/E LEIGH ST RICH  Closed  2022-01-28T16:02:00.000Z
# 3  600-BLK WESTOVER HILLS BLVD  Closed  2022-01-28T16:02:00.000Z
# 4  3300-BLK N ARTHUR ASHE BLVD  Closed  2022-01-28T16:00:00.000Z

# %%
# split X and Y coords by splitting
df[['X','Y']] = df['coords'].str.split(',', expand=True)

# %%
# Strip the square brackets from our X and Y coord columns
df['X']=df['X'].str.replace('[','')
df['Y']=df['Y'].str.replace(']','')

# %%
# start breaking down our columns into unique values
pd.unique(df['agency'])
# Out:
# array(['RFD', 'RPD', 'CCPD', 'HCPD', 'CCFD', 'DPW'], dtype=object)

# %% [markdown]
# #### 'RFD' - Richmond Fire Department
# #### 'RPD' - Richmond Police Department
# #### 'CCPD' - Chesterfield County Police Department
# #### 'HCPD' - Henrico County Police Department
# #### 'CCFD' - Chesterfield County Fire Department
# #### 'DPW' - Department of Public Works

# %%
# A count of how many calls came for each department
df.groupby('agency').count().sort_values(by='_id', ascending=False)
# Out:
#           _id  coords  district  incident  location  status  timeReceived  \
# agency
# RPD     34368   32295     34368     34368     34368   34368         34368
# HCPD    15240   14352     15240     15240     15240   15240         15240
# CCPD    13958   13958     13958     13958     13958   13958         13958
# CCFD     7634    7634      7634      7634      7634    7634          7634
# RFD      6582    6143      6582      6582      6582    6582          6582
# DPW        12      12        12        12        12      12            12
#
#             X      Y
# agency
# RPD     32295  32295
# HCPD    14352  14352
# CCPD    13958  13958
# CCFD     7634   7634
# RFD      6143   6143
# DPW        12     12

# %%
# Richmond Police department has more than double the next highest called emergency response department

# %%
a = pd.unique(df['incident'])

# %%
num = 1
for i in a:
    print(i + " - " + str(num))
    num += 1
# Out:
# # UTILITY INCIDENT , GAS LEAK - RUPTURED MAIN (OUTSIDE) - 1
# BURGLAR ALARM , INVESTIGATE - 2
# TRAFFIC COMPLAINT , INVESTIGATE - 3
# LARCENY , DPR Call - Take a Report - 4
# DISORDERLY , NUISANCE - 5
# # FIRE ALARM , SMOKE DETECTOR - 6
# PERSON DOWN , INVESTIGATE - 7
# DRUG/NARCOTICS OFFENSE , INVESTIGATE / OUTSIDE - 8
# ASSIST - OTHER AGENCY OR CALLER , OTHER AGENCY OR DEPARTMENT - 9
# DESTRUCTION OF PROPERTY , INVESTIGATE - 10
# BREAK & ENTER , JUST OCCURRED / IN-PROGRESS - 11
# DISORDERLY , INVESTIGATE - 12
# CRASH , PROPERTY DAMAGE - 13
# MISSING PERSON - JUVENILE 11  AND OLDER , INVESTIGATE - 14
# MENTAL SUBJECT , TDO / ECO - 15
# ASSIST - 16
# POLICE SERVICE - 17
# DISABLED VEHICLE--HA - 18
# RUNAWAY - 19
# BARKING DOG - 20
# TRAFFIC STOP - 21
# MISSING PERSON - 22
# HIT & RUN MVA - 23
# TRAFFIC LIGHTS OUT - 24
# MVA-NO INJ - 25
# ASSIST OTHER AGENCY - 26
# MEDICAL EMERGENCY - 27
# ASSAULT - 28
# FUNERAL ESCORT - 29
# DOMESTIC - 30
# POLICE PURSUIT - 31
# VANDALISM - 32
# TRESPASSING - 33
# SHOPLIFTING - 34
# SUSPICIOUS SITUATION - 35
# DISORDERLY/DRUNK - 36
# VEHICLE-STOLEN - 37
# ANIMAL - 38
# LARCENY - 39
# MERCHANT CHECK , OFFICER INITIATED - 40
# HOTSPOT-CURVE , OFFICER INITATED - 41
# DISTURBANCE - 42
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , CHEST PAIN - 43
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , ALTERED MENTAL STATUS - 44
# ROAD RAGE INCIDENT - 45
# CHECK THE WELFARE - 46
# WANTED PERSON , INVESTIGATE - 47
# WELFARE CHECK , INVESTIGATE - 48
# PARKING COMPLAINT , INVESTIGATE - 49
# AUTO LARCENY - 50
# CRASH , PERSONAL INJURY - 51
# FRAUD /FORGERY INCIDENT , DPR Call - Take a Report - 52
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , UNCONSCIOUSNESS/FAINTING - 53
# CRASH , HAZARD CONTROL - 54
# HARASSING / THREATENING PHONE CALLS , DPR Call - 55
# RECKLESS DRIVING , INVESTIGATE - 56
# MEDICAL ALARM - DEFIBRILLATOR , INVESTIGATE - 57
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , MEDICAL ALARM - 58
# E911 HANGUP - 59
# DEATH OF PERSON - 60
# SHOOTING REPORTED - 61
# WALKING ASSIGNMENT , OFFICER INITIATED - 62
# ACCIDENT - 63
# FIREARM VIOLATION - 64
# DOMESTIC TROUBLE , INVESTIGATE - 65
# # FIRE ALARM , GENERAL - 66
# ASSAULT , DPR Call - Take a Report (Non-Domestic &Simple) - 67
# ASSIST FIRE DEPARTMENT , TRAFFIC AND/OR CROWD CONTROL - 68
# MENTAL SUBJECT , INVESTIGATE - 69
# DISORDERLY , DPR CALL - ADVICE ONLY - 70
# LARCENY , JUST OCCURRED / IN-PROGRESS - 71
# SUSPICIOUS PERSON - 72
# VEHICLE-VIOLATION - 73
# DISABLED VEHICLE - 74
# REFERRAL FROM NGO OR GO , OFFICER INITIATED - 75
# SERVICE CALL - 76
# SILENT E911 CALL , INVESTIGATE - 77
# FRAUD /FORGERY INCIDENT , INVESTIGATE - 78
# ABANDONED VEHICLE , INVESTIGATE - 79
# WIRES DOWN (NO FIRE) , INVESTIGATE - 80
# ASSAULT , INVESTIGATE - 81
# LARCENY , TAKE A REPORT (Field Unit Required) - 82
# DISABLE VEHICLE - HAZARD , INVESTIGATE - 83
# STOLEN VEHICLE , DPR Call - Take a Report - 84
# POLICE INFORMATION - 85
# NOISE COMPLAINT - 86
# TRAFFIC STOP , OFFICER-INITIATED - 87
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , BREATHING PROBLEM - 88
# PARKING VIOLATION - 89
# VEHICLE-ABANDONED/DISABLED - 90
# BREAK & ENTER , INVESTIGATE - 91
# SUSPICIOUS , PERSON - 92
# DOMESTIC ASSAULT - 93
# SOLICITING - NOT PRO - 94
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , UNKNOWN PROBLEM/PERSON DOWN - 95
# WELFARE CHECK , EMS RESPONSE - 96
# RECOVERED VEHICLE , TAKE A REPORT - 97
# MENTAL SUBJECT , MENTAL SUBJECT EMERGENT - 98
# SUSPICIOUS , DPR/ADVICE - 99
# FIGHT - 100
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , STROKE - 101
# # ASSIST EMS , LIFTING ASSISTANCE - 102
# ASSIST - OTHER AGENCY OR CALLER , CITIZEN - 103
# # TRASH FIRE , DUMPSTER - 104
# FRAUD - 105
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , HEMORRHAGE - 106
# SUSPICIOUS , INVESTIGATE - 107
# FOUND PROPERTY - 108
# TROUBLE WITH JUVENIL - 109
# LOST PROPERTY , DPR CALL - TAKE A REPORT - 110
# INFORMATION ON PREVI - 111
# ABANDONED VEHICLE - 112
# INDECENT EXPOSURE , INVESTIGATE - 113
# # OTHER , SINGLE COMPANY - 114
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , HEART PROBLEM - 115
# ROBBERY , JUST OCCURRED / IN-PROGRESS - 116
# IN-PROGRESS (Assault or battery by mob) , INVESTIGATE - 117
# UTILITY PROBLEM - 118
# DOMESTIC TROUBLE , ASSIST OR STANDBY - 119
# DIRECT TRAFFIC - 120
# DISABLED VEHICLE - NON HAZARD - OCCUPPIED , INVESTIGATE - 121
# ASSAULT , JUST OCCURRED / IN-PROGRESS - 122
# LARCENY FROM AUTO - 123
# PD-HAZCON - 124
# LOUD MUSIC , INVESTIGATE - 125
# LARCENY , INVESTIGATE - 126
# PD RESPONSE FOR CRA - 127
# BURGLARY-RESIDENTIAL - 128
# OVERDOSE/POISONING , JUST OCCURRED - 129
# WANTED SUBJECT - 130
# ANIMAL CONTROL PD ON - 131
# # FIRE ALARM , CARBON MONOXIDE - 132
# DESTRUCTION OF PROPERTY , DPR Call - Take a Report - 133
# BREAKING & ENTERING - 134
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , SEIZURES - 135
# DOMESTIC TROUBLE , VIOLENT - 136
# SUSPICIOUS VEHICLE - 137
# # STRUCTURE FIRE , HOUSE FIRE - 138
# 911 HANG UP - 139
# DOMESTIC TROUBLE , DPR Call - Advice Only - 140
# RANDOM GUNFIRE , INVESTIGATE - 141
# RECKLESS DRIVING - 142
# MVA-WITH INJ - 143
# MISSING PERSON - ELDERLY / AT RISK , INVESTIGATE - 144
# STOLEN VEHICLE , JUST OCCURRED / IN- PROGRESS - 145
# # UTILITY INCIDENT , GAS LEAK/ODOR (INSIDE) - 146
# WEAPONS OFFENSE - 147
# SUBJECT STOP , OFFICER-INITIATED - 148
# PANIC/DURESS ALARM , INVESTIGATE - 149
# DRIVING UNDER THE IN - 150
# 911 ABANDONED - 151
# FOUND PROPERTY , INVESTIGATE - 152
# MOTOR VEHICLE ACCIDENT - 153
# EMS CALL - 154
# # TRASH FIRE , OTHER -  (SEE REMARKS) - 155
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , FALL - 156
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , CARDIAC/RESPIRATORY ARREST - 157
# DISABLED VEHICLE - NON HAZARD - UNOCCUPIED , INVESTIGATE - 158
# K9 OUTSIDE JURISDICT - 159
# ANNOYING PHONE CALLS - 160
# # STRUCTURE FIRE , APARTMENT FIRE - 161
# PUBLIC SERVICE - 162
# ASSIST - OTHER AGENCY OR CALLER - 163
# ARMED PERSON WITH , INVESTIGATE - 164
# SEX OFFENSE , INVESTIGATE - 165
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , OVERDOSE - POISONING - INGESTION - 166
# DISORDERLY , AGGRESSIVE - 167
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , PSYCHIATRIC PROBLEM - 168
# D.O.A. , INVESTIGATE - 169
# # ASSIST POLICE , FORCIBLE ENTRY - 170
# UNNECESSARY NOISE , INVESTIGATE - 171
# LOUD PARTY OR NOISE - 172
# INTOXICATED DRIVER , INVESTIGATE - 173
# TROUBLE UNKNOWN , INVESTIGATE - 174
# IN-PROGRESS (Assault or battery by mob) , IN-PROGRESS - 175
# SEX OFFENSE , JUST OCCURRED / IN-PROGRESS - 176
# INTOXICATED PERSON , INVESTIGATE - 177
# SHOOTING (PERSON SHOT) , JUST OCCURRED / IN-PROGRESS - 178
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , SHOOTING - 179
# # STRUCTURE FIRE , BUILDING FIRE - 180
# ROBBERY - 181
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , STABBING - 182
# STRUCTURE FIRE - 183
# TRESPASSING , INVESTIGATE - 184
# # FIRE STANDBY , SPECIAL-EVENT - 185
# STOLEN VEHICLE , TAKE A REPORT (Field Unit Required) - 186
# RECOVERED PROPERTY - 187
# OTHER - 188
# BOMB/SUSPICIOUS PACKAGE - 189
# # STRUCTURE FIRE , ELECTRICAL FIRE - 190
# PROSTITUTION , INVESTIGATE - 191
# MISSING PERSON , DPR Call - Take a Report Normal (NOT Juvenile or Elderly) - 192
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , PREGNANCY - 193
# CRASH , CITY PROPERTY - 194
# INDECENT EXPOSURE - 195
# SHOOTING - 196
# SPEEDING - 197
# JUVENILE PROBLEM - 198
# SEARCH WARRANT , INVESTIGATE - 199
# # LOCK-OUT , CHILD LOCKED IN VEHICLE - 200
# ASSIST FIRE DEPARTMENT , NON-EMERGENCY - 201
# PRISONER TRANSPORT , PRISONER TRANSPORT - 202
# PUBLIC WORKS , DPW - OTHER - 203
# THROWING OBJECTS AT - 204
# # ASSIST EMS , FORCIBLE ENTRY - 205
# # ELEVATOR INCIDENT - 206
# # ASSIST EMS , OTHER (SEE REMARKS) - 207
# # BRUSH FIRE , GRASS - 208
# # UTILITY INCIDENT , TRANSFORMER FIRE - 209
# BOMB THREAT (CALL DEC FOR EVENT INFO) , INVESTIGATE - 210
# OCCUPIED DISABLED VE - 211
# ID CALL ONLY - 212
# MISSING PERSON , TAKE A REPORT (Field Unit Required - 213
# DRAG RACING - 214
# # VEHICLE FIRE , CAR OR PICKUP - 215
# CAR JACKING , JUST OCCURRED / IN-PROGESS - 216
# # FIRE ALARM , SPRINKLER/WATERFLOW - 217
# CRASH , PERSON TRAPPED - 218
# FIRE - 219
# VEHICLE FIRE - 220
# DOMESTIC W/WEAP - 221
# DRUNK IN PUBLIC - 222
# ASSIST - OTHER AGENCY OR CALLER , TOW OR WRECKER SERVICE - 223
# # CHEMICAL MATERIALS , BIOHAZARD/BLOOD CLEAN UP - 224
# CHILD ABUSE NEGLECT - 225
# BURGLARY-COMMERCIAL - 226
# HIT & RUN W/PI - 227
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , DIABETIC PROBLEM - 228
# HOLD-UP ALARM COMMERCIAL , INVESTIGATE - 229
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , ABDOMINAL PAIN - 230
# # UTILITY INCIDENT , GAS LEAK/ODOR (OUTSIDE) - 231
# # UTILITY INCIDENT , WATER RELATED - 232
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , CHOKING - 233
# FOUND PROPERTY , FIRE ARM - 234
# # STRUCTURE FIRE , SMOKE/ODOR INSIDE STRUCTURE - 235
# # SMOKE INVESTIGATION - 236
# ROBBERY , JUST OCCURRED/ IN-PROGRESS - 237
# PHONE CALLS/LETTERS - 238
# # TRASH FIRE , BURN VIOLATION - 239
# SUBJECT PURSUIT , OFFICER-INITIATED - 240
# STOLEN PROPERTY - 241
# TRASH DUMPING - 242
# DISTUR W/WEAPON - 243
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , ALLERGIC REACTION - 244
# PUBLIC WORKS , TRAFFIC SIGNAL OUT/MALFUNCTION - 245
# SUSPICIOUS , PACKAGE - 246
# PUBLIC WORKS , STREET FLOODED - 247
# DELIVER MESSAGE - 248
# DESTRUCTION OF PROPERTY , JUST OCCURRED / IN- PROGRESS - 249
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , ASSAULT - 250
# # CHEMICAL MATERIALS , FUEL SPILL (SMALL) - 251
# PROWLER - 252
# UNAUTHORIZED USE OF - 253
# # FIRE ALARM , KEYPAD - 254
# ROBBERY , INVESTIGATE - 255
# MAYDAY/Deputy/Officer Down , INVESTIGATE - 256
# # FIRE ALARM , PULL STATION - 257
# # CHEMICAL MATERIALS , SMELL OR ODOR (NO SPILL) - 258
# BURGLAR ALARM , TAMPER WITH EQUIPMENT - 259
# VICE/ALCOHOL/NARCOTICS - 260
# TRAFFIC OFFENSE - 261
# BRUSH FIRE - 262
# WANTED PERSON , PROBATION & PAROLE SERVICE - (INVESTIGATE) - 263
# PROWLER , INVESTIGATE - 264
# GAS DRIVE OFF - 265
# # LOCK-OUT , HOUSE - 266
# OCCP STRUCTURE OR VEH , JUST OCCURRED/IN-PROGESS NON-EMS - 267
# PANHANDLING - 268
# MAYDAY/Deputy/Officer Down , MAYDAY FIRE/EMS UNIT - 269
# PUBLIC WORKS , TRASH IN STREET/SIDEWALK/ALLEY - 270
# # TRASH FIRE , DEBRIS - 271
# # CHEMICAL MATERIALS , CHEMICAL / VAPOR SPILL OR LEAK - 272
# ANIMAL BITE IN PROGRESS / WITH INJURIES , INVESTIGATE - 273
# REDUCED STRUCTURE FI - 274
# MISSING PERSON - JUVENILE 10 AND UNDER , INVESTIGATE - 275
# # FIRE STANDBY , VENUE - 276
# # STRUCTURE FIRE , UNKNOWN FIRE - 277
# OCCP STRUCTURE OR VEH , INVESTIGATE / NON - EMS - 278
# TRAFFIC PURSUIT , OFFICER-INITIATED - 279
# PROPERTY CASE - 280
# SERIOUS BRUSH - 281
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , BACK PAIN - 282
# GRAND LARCENY - 283
# STABBING , INVESTIGATE / NON-EMS - 284
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , SICK PERSON - 285
# SPECIAL FIRE - 286
# HIGH WATER-POLICE - 287
# # ASSIST POLICE , OTHER_(SEE REMARKS) - 288
# # VEHICLE FIRE , LIMITED ACCESS HIGHWAY - 289
# # BRUSH FIRE , MULCH - 290
# MAYDAY/Deputy/Officer Down , Officer-Initiated - 291
# STABBING , JUST OCCURRED / IN- PROGRESS - 292
# # FIRE ALARM , GAS ALARM (NON-SPECIFIED) - 293
# PUBLIC WORKS , MISSING/DAMAGED STOP SIGN - 294
# ASSAULT WITH DEADLY - 295
# HOLD-UP ALARM RESIDENTIAL , INVESTIGATE - 296
# TRESPASSING , DPR/ADVICE - 297
# WARRANT SERVICE - 298
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , TRAUMATIC INJURY - 299
# SHOOTING (PERSON SHOT) , INVESTIGATE / HOSPITAL - 300
# WEAPONS VIOLATION - 301
# BREAK & ENTER , DPR Call - Take a Report (Detached Shed/Garage) - 302
# DESK OFFICER CALL FO - 303
# UNSECURE BUILDING , INVESTIGATE - 304
# MENTAL SUBJECT , PRISONER TRANSPORT - 305
# LOST PROPERTY - 306
# # TECHNICAL RESCUE , CONFINED SPACE INCIDENT - 307
# FIRE RESPONSE TO MVA - 308
# CHIMNEY FIRE - 309
# # BRUSH FIRE , PROXIMITY TO STRUCTURE - 310
# INDECENT EXPOSURE , DPR Call - Take a Report - 311
# # MUTUAL AID , TO SCENE - 312
# WANTED PERSON , ASSIST/ADVICE - 313
# VANDALISM TO MAILBOX - 314
# ABANDONED BICYCLE , INVESTIGATE - 315
# TEST , TEST - 316
# # WATER RESCUE , RIVER/POND/LAKE - 317
# PUBLIC WORKS , TREE/LIMB IN ROADWAY/SIDEWALK - 318
# FIREWORKS - 319
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , BURN - 320
# LIQUOR LAW VIOLATION - 321
# # FIRE ALARM , HEAT DETECTOR - 322
# SUMMONS SERVICE - 323
# MULCH OR MEDIAN STRI - 324
# # STRUCTURE FIRE , GARAGE FIRE - 325
# LIFE OR DEATH EMERGENCY , ELECTROCUTION - 326
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , ELECTROCUTION - 327
# OVERDOSE - POLICE - 328
# HOLDING PERSON , INVESTIGATE - 329
# TRASH FIRE - 330
# # BRUSH FIRE , WOODS - 331
# # MUTUAL AID , STATION FILL IN - 332
# WANTED PERSON , ARMED WITH_____-(INVESTIGATE) - 333
# # UTILITY INCIDENT , WIRES ARCING - 334
# # UTILITY INCIDENT , WIRES DOWN (NO FIRE) - 335
# SUICIDE - 336
# MENTAL SUBJECT , PRISONER WATCH - 337
# ABDUCTION , INVESTIGATE - 338
# # CHEMICAL MATERIALS , FUEL SPILL (LARGE) - 339
# MACHINERY ENTRAPMENT - 340
# INDUSTRIAL ACCIDENT - 341
# DRUG/NARCOTICS OFFENSE , DPR CALL - ADVICE ONLY - 342
# ACTIVE_THREAT , IN PROGRESS - 343
# TRAFFIC ENFORCEMENT - 344
# FRAUD /FORGERY INCIDENT , JUST OCCURRED / IN-PROGRESS - 345
# PD-FIRE ALARM ACTIVA - 346
# # CHEMICAL MATERIALS , WHITE POWDER INCIDENT - 347
# # VEHICLE FIRE , PROXIMITY TO STRUCTURE - 348
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , EXPOSURE TO HEAT OR COLD - 349
# ELEVATED RESCUE - 350
# TECH RESCUE-MUTUAL A - 351
# # VEHICLE FIRE , SEMI/BUS/MOTOR HOME - 352
# WATER RECOVERY - 353
# VEHICLE-TOWED/STORED - 354
# EMERGENCY PURSUIT - 355
# TRENCH OR EARTH COLL - 356
# ABOVE WATER RESCUE - 357
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , INDUSTRIAL/MACHINERY ACCIDENT - 358
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , HEADACHE - 359
# BURGLAR ALARM , TAMPER - DISARM W/O PROPER CODE - 360
# # TECHNICAL RESCUE , HIGH ANGLE INCIDENT - 361
# # TAKE FIRE REPORT - 362
# # FIRE ALARM , TROUBLE/TAMPER/SUPERVISORY - 363
# GAMBLING , INVESTIGATE - 364
# STABBING , INVESTIGATE - 365
# PARKING COMPLAINT , DPR/ADVICE - 366
# # EMS - 1ST RESP CALL (FIRE RESP ONLY) , MULTIPLE COMPLAINTS - 367
# SILENT E911 CALL - WIRELESS PHASE 2 , INVESTIGATE - 368
# STRUCTURE COLLAPSE - 369
# CAR JACKING , INVESTIGATE - 370
# SCHOOL CROSSING ASSI - 371
# # STRUCTURE FIRE , CHIMNEY FIRE - 372
# IMPERSONATION - 373
# ABDUCTION - 374
# LOCK-OUT , ANIMAL LOCKED IN VEHICLE - 375
# # OTHER , UNKNOWN FIRE (NON-STRUCTURE) - 376
# # LOCK-OUT , ANIMAL LOCKED IN VEHICLE - 377
# OVERDOSE/POISONING , OVERDOSE INTENTIONAL - 378
# MENTAL SUBJECT , REFERRED TO CRISIS LINE - 379
# DEAD ON ARRIVAL - PO - 380
# TAMPERING PROPERTY - 381

# %%
X_list = pd.unique(df['X'])

# %%
df.to_csv('test.csv')

# %%
# PLOT onto a map
# for now, we'll have to drop the null rows
#define values
values = ['0', '', 0,'-111.24']

#drop rows that contain any value in the list
df = df[df.X.isin(values) == False]

# %%
df['X'] = df['X'].astype(float)
df['Y'] = df['Y'].astype(float)

# %%
BBox = ((df.X.min(),   df.X.max(), df.Y.min(), df.Y.max()))

# %%
BBox
# Out:
# (0.456983918826435, 42.8092, -85.9374, 57.86667)
