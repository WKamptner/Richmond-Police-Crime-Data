# %%
import os
import pandas as pd
import numpy as nm
import seaborn as sns

# %%
df = pd.read_csv('calls.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77794 entries, 0 to 77793
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           77794 non-null  object
#  1   agency        77794 non-null  object
#  2   coords        74394 non-null  object
#  3   district      77794 non-null  object
#  4   incident      77794 non-null  object
#  5   location      77794 non-null  object
#  6   status        77794 non-null  object
#  7   timeReceived  77794 non-null  object
# dtypes: object(8)
# memory usage: 4.7+ MB

# %%
df.head()
# Out:
#                                 _id agency  \
# 0  0411a692604fc30d2b7e90768bea27cb    RFD
# 1  a6778ad2a905749daa2d7ba3571b5943    RPD
# 2  ea9f720bdb4e40f25c6da4978692fd9d    RPD
# 3  d34129688e6724e10872e708e8476b43    RPD
# 4  7e22a1550c625e11e2c6905b7c1c9f1f    RPD
#
#                                    coords  district  \
# 0  [37.52257549999999,-77.48004999999999]  Richmond
# 1                 [37.5469025,-77.542215]  Richmond
# 2                [37.5473731,-77.4366354]  Richmond
# 3                  [37.514049,-77.489561]  Richmond
# 4                [37.5773242,-77.4625667]  Richmond
#
#                                             incident  \
# 0  # UTILITY INCIDENT , GAS LEAK - RUPTURED MAIN ...
# 1                        BURGLAR ALARM , INVESTIGATE
# 2                    TRAFFIC COMPLAINT , INVESTIGATE
# 3                 LARCENY , DPR Call - Take a Report
# 4                              DISORDERLY , NUISANCE
#
#                       location  status              timeReceived
# 0           1800-BLK W 45TH ST  Closed  2022-01-28T16:09:00.000Z
# 1        3700-BLK WAKEFIELD RD  Closed  2022-01-28T16:07:00.000Z
# 2     MOSBY ST/E LEIGH ST RICH  Closed  2022-01-28T16:02:00.000Z
# 3  600-BLK WESTOVER HILLS BLVD  Closed  2022-01-28T16:02:00.000Z
# 4  3300-BLK N ARTHUR ASHE BLVD  Closed  2022-01-28T16:00:00.000Z

# %%
# split X and Y coords by splitting
df[['X','Y']] = df['coords'].str.split(',', expand=True)

# %%
# Strip the square brackets from our X and Y coord columns
df['X']=df['X'].str.replace('[','')
df['Y']=df['Y'].str.replace(']','')

# %%
df
# Out:
#                                     _id agency  \
# 0      0411a692604fc30d2b7e90768bea27cb    RFD
# 1      a6778ad2a905749daa2d7ba3571b5943    RPD
# 2      ea9f720bdb4e40f25c6da4978692fd9d    RPD
# 3      d34129688e6724e10872e708e8476b43    RPD
# 4      7e22a1550c625e11e2c6905b7c1c9f1f    RPD
# ...                                 ...    ...
# 77789  f1582d0412896d0126fb8ace12c69462   CCPD
# 77790  d6e292b8f009eb9e88dd5822734d0ebb    RPD
# 77791  d2739d4dbdff88d03b6ccd04b21070f9    RPD
# 77792  f4f04f6e7602c76e92a602276962a9dd    RPD
# 77793  52461db559177d1b10848b85ff00edef    RPD
#
#                                        coords      district  \
# 0      [37.52257549999999,-77.48004999999999]      Richmond
# 1                     [37.5469025,-77.542215]      Richmond
# 2                    [37.5473731,-77.4366354]      Richmond
# 3                      [37.514049,-77.489561]      Richmond
# 4                    [37.5773242,-77.4625667]      Richmond
# ...                                       ...           ...
# 77789                     [37.43072,-77.4411]  Chesterfield
# 77790                    [37.57997,-77.50921]      Richmond
# 77791                      [37.5385,-77.4343]      Richmond
# 77792                      [37.5385,-77.4343]      Richmond
# 77793                      [37.5385,-77.4343]      Richmond
#
#                                                 incident  \
# 0      # UTILITY INCIDENT , GAS LEAK - RUPTURED MAIN ...
# 1                            BURGLAR ALARM , INVESTIGATE
# 2                        TRAFFIC COMPLAINT , INVESTIGATE
# 3                     LARCENY , DPR Call - Take a Report
# 4                                  DISORDERLY , NUISANCE
# ...                                                  ...
# 77789                                            RUNAWAY
# 77790                              DISORDERLY , NUISANCE
# 77791                    PARKING COMPLAINT , INVESTIGATE
# 77792                            CRASH , PROPERTY DAMAGE
# 77793                           DISORDERLY , INVESTIGATE
#
#                                 location      status  \
# 0                     1800-BLK W 45TH ST      Closed
# 1                  3700-BLK WAKEFIELD RD      Closed
# 2               MOSBY ST/E LEIGH ST RICH      Closed
# 3            600-BLK WESTOVER HILLS BLVD      Closed
# 4            3300-BLK N ARTHUR ASHE BLVD      Closed
# ...                                  ...         ...
# 77789           6800 JEFFERSON DAVIS HWY  Dispatched
# 77790                 5400-BLK STOKES LN     Enroute
# 77791         CLEVELAND ST/PARK AVE RICH     Enroute
# 77792  N BELVIDERE ST/W MARSHALL ST RICH     Enroute
# 77793                   2600-BLK HULL ST     Enroute
#
#                    timeReceived                  X                   Y
# 0      2022-01-28T16:09:00.000Z  37.52257549999999  -77.48004999999999
# 1      2022-01-28T16:07:00.000Z         37.5469025          -77.542215
# 2      2022-01-28T16:02:00.000Z         37.5473731         -77.4366354
# 3      2022-01-28T16:02:00.000Z          37.514049          -77.489561
# 4      2022-01-28T16:00:00.000Z         37.5773242         -77.4625667
# ...                         ...                ...                 ...
# 77789  2022-04-20T23:38:00.000Z           37.43072            -77.4411
# 77790  2022-04-20T23:20:00.000Z           37.57997           -77.50921
# 77791  2022-04-20T23:18:00.000Z            37.5385            -77.4343
# 77792  2022-04-20T23:50:00.000Z            37.5385            -77.4343
# 77793  2022-04-20T23:48:00.000Z            37.5385            -77.4343
#
# [77794 rows x 10 columns]
